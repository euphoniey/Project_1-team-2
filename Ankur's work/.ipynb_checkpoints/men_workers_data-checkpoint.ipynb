# %%
# Dependencies and Setup
import pandas as pd
import scipy.stats as st

# Study data files
men_path = "data/Men_workers.csv"

# Read the mouse data and the study results
men_results = pd.read_csv(men_path)
men_results
# Out:
#                                            Occupation Number\nof\nworkers  \
# 0            Total, full-time wage and salary workers              64,142
# 1   Management, professional, and related occupations              23,685
# 2       Business and financial operations occupations               2,914
# 3                Professional and related occupations              13,017
# 4            Architecture and engineering occupations               2,541
# 5            Community and social service occupations                 754
# 6                                   Legal occupations                 651
# 7        Education, training, and library occupations               1,915
# 8   Arts, design, entertainment, sports, and media...               1,052
# 9   Healthcare practitioners and technical occupat...               1,800
# 10                                Service occupations               7,948
# 11   Food preparation and serving related occupations               2,210
# 12  Building and grounds cleaning and maintenance ...               2,373
# 13              Personal care and service occupations                 746
# 14                       Sales and office occupations               9,548
# 15      Office and administrative support occupations               3,926
# 16  Natural resources, construction, and maintenan...              11,030
# 17  Installation, maintenance, and repair occupations               4,140
# 18  Production, transportation, and material movin...              11,932
# 19     Transportation and material moving occupations               6,305
#
#    Median\nweekly\nearnings Standard error of median
# 0                     $973                       $3
# 1                     1,468                        8
# 2                     1,383                       22
# 3                     1,425                        9
# 4                     1,528                       16
# 5                       984                       21
# 6                     1,910                       31
# 7                     1,235                       17
# 8                     1,151                       14
# 9                     1,383                       27
# 10                      641                        6
# 11                      533                        9
# 12                      604                        5
# 13                      638                       25
# 14                      846                        8
# 15                      738                        8
# 16                      834                        7
# 17                      936                        9
# 18                      762                        5
# 19                      724                        7

# %%
men_workers = pd.DataFrame(men_results)
men_workers_df = men_workers.rename(columns={"Number\nof\nworkers": "Total Number of Men",
                                                 "Median\nweekly\nearnings": "Median Earnings(total)"}).drop(0)

#men_workers_df.dtypes

men_numbers = men_workers_df["Total Number of Men"].str.replace(",","").astype(int)

new_men_df = men_workers_df.drop(columns = ['Total Number of Men'])
new_men_df

men_numbers_df = pd.DataFrame(men_numbers)
men_numbers_df

final_men_df = pd.concat([new_men_df, men_numbers_df], 1)
final_men_df

sorted_df = final_men_df.sort_values(by=["Total Number of Men"], ascending = False)

men_df = sorted_df[['Occupation','Total Number of Men','Median Earnings(total)', 'Standard error of median' ]]
men_df
# Out:
#                                            Occupation  Total Number of Men  \
# 1   Management, professional, and related occupations                23685
# 3                Professional and related occupations                13017
# 18  Production, transportation, and material movin...                11932
# 16  Natural resources, construction, and maintenan...                11030
# 14                       Sales and office occupations                 9548
# 10                                Service occupations                 7948
# 19     Transportation and material moving occupations                 6305
# 17  Installation, maintenance, and repair occupations                 4140
# 15      Office and administrative support occupations                 3926
# 2       Business and financial operations occupations                 2914
# 4            Architecture and engineering occupations                 2541
# 12  Building and grounds cleaning and maintenance ...                 2373
# 11   Food preparation and serving related occupations                 2210
# 7        Education, training, and library occupations                 1915
# 9   Healthcare practitioners and technical occupat...                 1800
# 8   Arts, design, entertainment, sports, and media...                 1052
# 5            Community and social service occupations                  754
# 13              Personal care and service occupations                  746
# 6                                   Legal occupations                  651
#
#    Median Earnings(total) Standard error of median
# 1                   1,468                        8
# 3                   1,425                        9
# 18                    762                        5
# 16                    834                        7
# 14                    846                        8
# 10                    641                        6
# 19                    724                        7
# 17                    936                        9
# 15                    738                        8
# 2                   1,383                       22
# 4                   1,528                       16
# 12                    604                        5
# 11                    533                        9
# 7                   1,235                       17
# 9                   1,383                       27
# 8                   1,151                       14
# 5                     984                       21
# 13                    638                       25
# 6                   1,910                       31

# %%
import matplotlib.pyplot as plt

men_df.plot(kind='bar', x="Occupation", y="Total Number of Men", 
              color = 'blue', title ='Occupational diversity', alpha=0.5, align="center", figsize=(18,5))

plt.xlabel("Occupation")
plt.ylabel("Total Number of Men")
plt.show()
